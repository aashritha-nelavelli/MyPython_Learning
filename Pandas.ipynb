# %% [markdown]
# ## Introductions to Pandas
# - Data structure for manipulating data
# - Introduction to Series in Pandas
# - Introduction to Dataframe in Pandas
# - Why Pandas is used for  data science
# - Advantages

# %% [markdown]
# Why Pandas is used for Data Science
# - Pandas is generally used for data science but have you wondered why? - This is because pandas is used in conjunction with other libraries that are used for data science.
# - It is built on the top of the NumPy library which means that a lot of structures of NumPy are used or replicated in Pandas.
# - The data produced by Pandas is often used as input for plotting functions of Matplotlib, statistical analysis in SciPy, machine learning algorithm in Scikit-learn.
# - Pandas program can be run from any text editor but it is recommended to use Jupyter Notebook for this as Jupyter given the ability to execute code in a particular cell rather than executing the entire file.
# - Jupyter also provides an easy way to visualize pandas dataframe and plots.

# %% [markdown]
# Advantages
# - - Fast and efficient for manipulating and analyzing data.
# - - Data from different file objects can be loaded.
# - - Easy handling of missing data (represented as NaN) in floating point as well as non-floating point data
# - - Size mutability: columns can be inserted and deleted from DataFrame and higher dimensional objects
# - - Data set merging and joining.
# - - Flexible reshaping and pivoting of data sets
# - - Provides time-series functionality.
# - - Powerful group by functionality for performing split-apply-combine operations on data sets.

# %% [markdown]
# Introduction to Pandas in Python
# - Pandas is an open-source library that is made mainly for working with relational or labeled data both easily and intuitively.
# - It provides various data structures and operations for manipulating numerical data and time series.
# - This library is built on the top of the NumPy library.
# - Pandas is fast and it has high-performance & productivity for users.
# - After the pandas has been installed into the system, you need to import the library. This module is generally imported as –”import pandas as pd”
# - Here, pd is referred to as an alias to the Pandas. However, it is not necessary to import the library using alias, it just helps in writing less amount of code everytime a method or property is called.
# - Pandas generally provide two data structure for manipulating data, They are:
# - - Series
# - - DataFrame

# %%
import pandas as pd

# %% [markdown]
# Series
# - Pandas Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.).
# - The axis labels are collectively called index. Pandas Series is nothing but a column in an excel sheet.
# - Labels need not be unique but must be a hashable type. The object supports both integer and label-based indexing and provides a host of methods for performing operations involving the index.
#
# CREATING A SERIES
#
# - In the real world, a Pandas Series will be created by loading the datasets from existing storage, storage can be SQL Database, CSV file, and Excel file. Pandas Series can be created from the lists, dictionary, and from a scalar value etc.

# %%
data=[30,32,34.5,29.8,50.4]
S=pd.Series(data)
S
# Out:
# 0    30.0
# 1    32.0
# 2    34.5
# 3    29.8
# 4    50.4
# dtype: float64

# %% [markdown]
# DataFrame in pandas
# - Pandas DataFrame is two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns).
# - A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
# - Pandas DataFrame consists of three principal components, the data, rows, and columns.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Creating a PANDAS DATAFRAME
# - In the real world, a Pandas DataFrame will be created by loading the datasets from existing storage, storage can be SQL Database, CSV file, and Excel file.
# - Pandas DataFrame can be created from the lists, dictionary, and from a list of dictionary etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df=pd.DataFrame(data)
df
# Out:
#       0
# 0  30.0
# 1  32.0
# 2  34.5
# 3  29.8
# 4  50.4

# %%
list1=[2,8,9,56,7]
list2=[21,8,12,57,9]

# %%
pd.Series(list2)+pd.Series(list1)
# Out:
# 0     23
# 1     16
# 2     21
# 3    113
# 4     16
# dtype: int64

# %%
pd.Series(list2)-pd.Series(list1)
# Out:
# 0    19
# 1     0
# 2     3
# 3     1
# 4     2
# dtype: int64

# %%
pd.Series(list2)*pd.Series(list1)
# Out:
# 0      42
# 1      64
# 2     108
# 3    3192
# 4      63
# dtype: int64

# %%
pd.Series(list2)/pd.Series(list1)
# Out:
# 0    10.500000
# 1     1.000000
# 2     1.333333
# 3     1.017857
# 4     1.285714
# dtype: float64

# %%
my_dict={"ayan":50,'asmi':56,"raj":68,"lav":70}
df=pd.Series(my_dict)
df
# Out:
# ayan    50
# asmi    56
# raj     68
# lav     70
# dtype: int64

# %%
list1=['Ayan','Asmi','Raj','Akku']
list2=[94,97,96,98]

df=pd.DataFrame()
df['Names']=list1
df['Marks']=list2

df
# Out:
#   Names  Marks
# 0  Ayan     94
# 1  Asmi     97
# 2   Raj     96
# 3  Akku     98

# %%
list3=['Trv','Aurangabad','Sydney','Manipal']
df_2=pd.DataFrame()

df_2['Names']=list1
df_2['City']=list3

df_2
# Out:
#   Names        City
# 0  Ayan         Trv
# 1  Asmi  Aurangabad
# 2   Raj      Sydney
# 3  Akku     Manipal

# %%
df_concat=pd.concat([df,df_2]) # by default axis is taken as 0
df_concat
# Out:
#   Names  Marks        City
# 0  Ayan   94.0         NaN
# 1  Asmi   97.0         NaN
# 2   Raj   96.0         NaN
# 3  Akku   98.0         NaN
# 0  Ayan    NaN         Trv
# 1  Asmi    NaN  Aurangabad
# 2   Raj    NaN      Sydney
# 3  Akku    NaN     Manipal

# %%
df_append=df.append(df_2)
df_append
# Out:
#   Names  Marks        City
# 0  Ayan   94.0         NaN
# 1  Asmi   97.0         NaN
# 2   Raj   96.0         NaN
# 3  Akku   98.0         NaN
# 0  Ayan    NaN         Trv
# 1  Asmi    NaN  Aurangabad
# 2   Raj    NaN      Sydney
# 3  Akku    NaN     Manipal

# %%
df_concat=pd.concat([df,df_2],axis=1)
df_concat
# Out:
#   Names  Marks Names        City
# 0  Ayan     94  Ayan         Trv
# 1  Asmi     97  Asmi  Aurangabad
# 2   Raj     96   Raj      Sydney
# 3  Akku     98  Akku     Manipal
